# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# # API Bağlantısının Yapılması

# %%
# !pip install tweepy

# %%
import tweepy, codecs
import configparser

# %%
consumer_key = 'U74zu1DaYRyZwJXqMaBmjTB7y'
consumer_secret = 'qPxEPi9UCoTxK15Inen5tzMZlqhokdpvFr0nws9OXyZbsECYn6'
access_token = '993952599752749056-vRbMlsIIFgFz3u9CjWLM2C5Vj47QFno'
access_token_secret = 'TWfyanQKQ26mXJHzPZZANXvDPiDgmbioKRFuuhf43GUbv'


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
me = api.get_user(screen_name = "mustafa_aktaas")

# %%
me.screen_name
# Out:
# 'mustafa_aktaas'

# %%
me.followers_count
# Out:
# 87

# %%
me.friends
# Out:
# <bound method User.friends of User(_api=<tweepy.api.API object at 0x0000028C329DEFA0>, _json={'id': 993952599752749056, 'id_str': '993952599752749056', 'name': 'Mustafa Aktaş', 'screen_name': 'mustafa_aktaas', 'location': '', 'profile_location': None, 'description': '', 'url': 'https://t.co/in88AMiJoR', 'entities': {'url': {'urls': [{'url': 'https://t.co/in88AMiJoR', 'expanded_url': 'http://www.instagram.com/mustafa_aktaas', 'display_url': 'instagram.com/mustafa_aktaas', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 87, 'friends_count': 159, 'listed_count': 0, 'created_at': 'Tue May 08 20:35:41 +0000 2018', 'favourites_count': 708, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 16, 'lang': None, 'status': {'created_at': 'Sat Jan 08 19:03:04 +0000 2022', 'id': 1479891423176675343, 'id_str': '1479891423176675343', 'text': '@bahadr_tryk Sen yazana kadar 8 oldular', 'truncated': False, 'entit
# ...

# %%
for friend in me.friends(count = 5):
    print(friend.screen_name)
# Out:
# asginnir
# Credytemp
# beegumkilinc
# duygunalsa
# ParibuDestek

# %%
user = api.get_user(screen_name = "beegumkilinc")

# %%
user.followers_count
# Out:
# 558

# %%
user.profile_image_url
# Out:
# 'http://pbs.twimg.com/profile_images/1548626785885163521/L5XklKKf_normal.jpg'

# %%
dir(user)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow',
#  'follow_request_sent',
#  'follower_ids',
#  'followers',
#  'followers_count',
#  'following',
#  'friends',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'list_memberships',
#  'list_ownerships',
#  'list_subscriptions',
#  'listed_count',
# ...

# %%
public_tweets = api.home_timeline(count = 5)

# %%
dir(tweet)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'parse',
#  'parse_list',
#  'place',
#  'possibly_sensitive',
#  'possibly_sensitive_appealable',
#  'retweet',
#  'retweet_count',
#  'retweeted',
# ...

# %%
for tweet in public_tweets:
    print(tweet.text)
    print(tweet.user)
# Out:
# 📹 Joao Pedro'nun ilk günü saat 20.00'de Fenerbahçe YouTube Katıl'da!
#
# Hemen katılmak için 👇
#
# https://t.co/WYcAwBHCN7 https://t.co/lmodwlTVD0
# ...

# %%
name = "beegumkilinc"
tweet_count = 10
user_timeline = api.user_timeline(screen_name = name,count = 10)

# %%
for tweet in user_timeline:
    print(tweet.text)
# Out:
# RT @darksideofrockk: allah scorpions'a bir daha still loving you yazdırmasın
# RT @bucheongayi: abla kelimesi belli bi cinsiyet degil
# RT @RockandMetalll: Kalıp senin yanında uzanıp koynuna
# Yarım kalan o şarabı içmeliydim
#
#  https://t.co/S0G08CLp5E
# RT @RockandMetalll: Every breath you take and every move you make
# Every bond you break every step you take I'll be watching you
#
# The Police…
# Yalovanın nüfusunun yarısı https://t.co/awqNNhw4sQ
# @yeteryavyeter portakal parçacıklı kısmı çok önemli.
# @BeratYildiz01 Ağzının tadını biliyormuş ablaaamm
# @uzulmezeh
# Cappy pulpy portakal parçacıklı

# %%
retweets = api.get_retweets_of_me(count = 10)

# %%
for retweet in retweets:
    print(retweet.text)

# %%
#hastag

# %%
tweets = api.search_tweets(q = "#Vergi", lang = "tr", result_type = "popular", count = 200)

# %%
tweets
# Out:
# []

# %%
dir(api)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_list_member',
#  'add_list_members',
#  'auth',
#  'available_trends',
#  'cache',
#  'cached_result',
#  'chunked_upload',
#  'chunked_upload_append',
#  'chunked_upload_finalize',
#  'chunked_upload_init',
#  'closest_trends',
#  'create_block',
#  'create_favorite',
#  'create_friendship',
#  'create_list',
#  'create_media_metadata',
#  'create_mute',
#  'create_saved_search',
#  'delete_direct_message',
#  'destroy_block',
#  'destroy_favorite',
#  'destroy_friendship',
#  'destroy_list',
#  'destroy_mute',
#  'destroy_saved_search',
#  'destroy_status',
# ...

# %%
# ?api.search_30_day
# Out:
# Signature: api.search_30_day(label, query, **kwargs)
# Docstring:
# search_30_day(label, query, *, tag, fromDate, toDate, maxResults,                          next)
#
# Premium search that provides Tweets posted within the last 30 days.
#
# Parameters
# ----------
# label
#     The (case-sensitive) label associated with your search developer
#     environment, as displayed at
#     https://developer.twitter.com/en/account/environments.
# query
#     The equivalent of one premium rule/filter, with up to 1,024
#     characters (256 with Sandbox dev environments).
#
#     This parameter should include ALL portions of the rule/filter,
#     including all operators, and portions of the rule should not be
#     separated into other parameters of the query.
# tag
#     Tags can be used to segregate rules and their matching data into
#     different logical groups. If a rule tag is provided, the rule tag
#     is included in the 'matching_rules' attribute.
#
# ...

# %%
# ?api.search_tweets
# Out:
# Signature: api.search_tweets(q, **kwargs)
# Docstring:
# search_tweets(q, *, geocode, lang, locale, result_type, count,                          until, since_id, max_id, include_entities)
#
# Returns a collection of relevant Tweets matching a specified query.
#
# Please note that Twitter's search service and, by extension, the Search
# API is not meant to be an exhaustive source of Tweets. Not all Tweets
# will be indexed or made available via the search interface.
#
# .. note::
#
#     Twitter's standard search API only "searches against a sampling of
#     recent Tweets published in the past 7 days."
#
#     If you're specifying an ID range beyond the past 7 days or there
#     are no results from the past 7 days, then no results will be
#     returned.
#
#     See `Twitter's documentation on the standard search API`_ for more
#     information.
#
# .. note::
#
#     In API v1.1, the response format of the Search API has been
# ...

# %%
for vergi in tweets:
    print(vergi.text)

# %%
for erdogan in tweets:
    print(erdogan.text)

# %%
tweets = api.search_tweets(q = "#Uzungöl", lang = "tr", result_type = "popular", count = 50)

# %%
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000028C329DEFA0>, _json={'created_at': 'Thu Jul 21 20:15:48 +0000 2022', 'id': 1550212970155745280, 'id_str': '1550212970155745280', 'text': "İki günde #Bayburt, #Gümüşhane, #Trabzon ve #Rize'yi ziyaret ettik. \n\nVatandaşlarımız hayat pahalılığından, her yer… https://t.co/PNny8s9iUk", 'truncated': True, 'entities': {'hashtags': [{'text': 'Bayburt', 'indices': [10, 18]}, {'text': 'Gümüşhane', 'indices': [20, 30]}, {'text': 'Trabzon', 'indices': [32, 40]}, {'text': 'Rize', 'indices': [44, 49]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/PNny8s9iUk', 'expanded_url': 'https://twitter.com/i/web/status/1550212970155745280', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'result_type': 'popular', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, '
# ...

# %%
def tweets_df(tweets):
    id_list = [tweet.id for tweet  in tweets]
    import pandas as pd
    data_set = pd.DataFrame(id_list, columns = ["id"])
    
    data_set["text"] = [tweet.text for tweet in tweets]
    data_set["created_at"] = [tweet.created_at for tweet in tweets]
    data_set["retweet_count"] = [tweet.retweet_count for tweet in tweets]
    data_set["user_screen_name"] = [tweet.author.screen_name for tweet in tweets]
    data_set["user_followers_count"] = [tweet.author.followers_count for tweet in tweets]
    data_set["user_location"] = [tweet.author.location for tweet in tweets]
    data_set["Hashtags"] = [tweet.entities.get('hashtags') for tweet in tweets]
    
    return data_set

# %%
data = tweets_df(tweets)

# %%
data
# Out:
#                     id                                               text  \
# 0  1547271800475815937  büyük talan ve yıkımdan 15 yıl önceleri;\nTRT’...
#
#                  created_at  retweet_count user_screen_name  \
# 0 2022-07-13 17:28:38+00:00            233         s_turpcu
#
#    user_followers_count user_location  \
# 0                 48448
#
#                                      Hashtags
# 0  [{'text': 'uzungöl', 'indices': [48, 56]}]

# %%
data.to_csv("data_twitter_trabzon.csv")

# %%
tweets = api.search_tweets(q = "#Ferrari",result_type = "recent", count = 2000)

# %%
for ferrari in tweets:
    print(ferrari.text)
# Out:
# aldilà di come é andata la gara, io sono rimasto a qua
# #Ferrari #Leclerc #Sainz #Formula1 https://t.co/nW3QGd4JlN
# RT @RaghavedraPR: Ferrari 296 GTB @Ferrari #Ferrari #FerrariFriday #Supercars #F40 @Ferrari @adda_89 @Evil__Mia @ItaliAuto @alfamale87 @ren…
# RT @Edwin93313152: PowerPro Maxcuatro Braid is a braided line offering power and sensitivity for fishing enthusiasts.
# Check out full post h…
# PowerPro Maxcuatro Braid is a braided line offering power and sensitivity for fishing enthusiasts.
# Check out full p… https://t.co/LzN1PJHeZ0
# @ScuderiaFerrari @Carlossainz55 @Charles_Leclerc And 16 if #binottoout no be stupid #ferrari is a shit worst in str… https://t.co/8IjGYh5D2b
# RT @cesarbecerraf1: #Ferrari tienes bien ordenado sus planes ahora en #FrenchGP el Plan con #Leclerc era Plan B = Barreras
#
# Allí lo tienen…
# To be the best amongst the best @F1 you need to push to the limit and beyond @ScuderiaFerrari. We go again in Hunga… https://t.co/g4RYwjszWM
# ...

# %%
def tweets_df(tweets):
    id_list = [tweet.id for tweet  in tweets]
    import pandas as pd
    data_set = pd.DataFrame(id_list, columns = ["id"])
    
    data_set["text"] = [tweet.text for tweet in tweets]
    data_set["created_at"] = [tweet.created_at for tweet in tweets]
    data_set["retweet_count"] = [tweet.retweet_count for tweet in tweets]
    data_set["user_screen_name"] = [tweet.author.screen_name for tweet in tweets]
    data_set["user_followers_count"] = [tweet.author.followers_count for tweet in tweets]
    data_set["user_location"] = [tweet.author.location for tweet in tweets]
    data_set["Hashtags"] = [tweet.entities.get('hashtags') for tweet in tweets]
    
    return data_set

# %%
data = tweets_df(tweets)

# %%
data.head(1000)
# Out:
#                      id                                               text  \
# 0   1551310196701528066  aldilà di come é andata la gara, io sono rimas...
# 1   1551310080099815424  RT @RaghavedraPR: Ferrari 296 GTB @Ferrari #Fe...
# 2   1551309769457254402  RT @Edwin93313152: PowerPro Maxcuatro Braid is...
# 3   1551309746849955840  PowerPro Maxcuatro Braid is a braided line off...
# 4   1551309743511244802  @ScuderiaFerrari @Carlossainz55 @Charles_Lecle...
# ..                  ...                                                ...
# 95  1551302476187504641  The 250 GTE deserves a post of its own. The ow...
# 96  1551302473477894145  Ferrari SF90\n\n@ferrari @autosnacion\n\n#ferr...
# 97  1551302344415088642  Clean Nissan Skyline GTR, R32 (1991) spotted i...
# 98  1551302341466460160  RT @michele69028102: #ferrari roma https://t.c...
# 99  1551302333430222848  Beauty of Bane (3840X 2880) #bugatti #ferrari ...
#
#                   created_at  retweet_count user_screen_name  \
# ...

# %%
# ?api.search_tweets
# Out:
# Signature: api.search_tweets(q, **kwargs)
# Docstring:
# search_tweets(q, *, geocode, lang, locale, result_type, count,                          until, since_id, max_id, include_entities)
#
# Returns a collection of relevant Tweets matching a specified query.
#
# Please note that Twitter's search service and, by extension, the Search
# API is not meant to be an exhaustive source of Tweets. Not all Tweets
# will be indexed or made available via the search interface.
#
# .. note::
#
#     Twitter's standard search API only "searches against a sampling of
#     recent Tweets published in the past 7 days."
#
#     If you're specifying an ID range beyond the past 7 days or there
#     are no results from the past 7 days, then no results will be
#     returned.
#
#     See `Twitter's documentation on the standard search API`_ for more
#     information.
#
# .. note::
#
#     In API v1.1, the response format of the Search API has been
# ...

# %%
tweets = api.search_tweets(q = "#tweetstappen", result_type = "recent", count = 2000)

# %%
for xd in tweets:
    print(xd.user)
# Out:
# User(_api=<tweepy.api.API object at 0x000002128CEDEC70>, _json={'id': 1328977569266294786, 'id_str': '1328977569266294786', 'name': 'Obaidullah', 'screen_name': 'Obaidul25763534', 'location': '', 'description': "I'm creating visualizations for 9+ years. I work with architects, interior designers, industrial designers and manifacturers for turning their designs.", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 21, 'friends_count': 11, 'listed_count': 0, 'created_at': 'Wed Nov 18 08:25:28 +0000 2020', 'favourites_count': 15, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 3607, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/132
# ...

# %%
dir(xd)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'metadata',
#  'parse',
#  'parse_list',
#  'place',
#  'possibly_sensitive',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweets',
#  'source',
# ...

# %%
def tweets_df(tweets):
    id_list = [tweet.id for tweet  in tweets]
    import pandas as pd
    data_set = pd.DataFrame(id_list, columns = ["id"])
    
    data_set["text"] = [tweet.text for tweet in tweets]
    data_set["created_at"] = [tweet.created_at for tweet in tweets]
    data_set["retweet_count"] = [tweet.retweet_count for tweet in tweets]
    data_set["user_screen_name"] = [tweet.author.screen_name for tweet in tweets]
    data_set["user_followers_count"] = [tweet.author.followers_count for tweet in tweets]
    data_set["user_location"] = [tweet.author.location for tweet in tweets]
    data_set["Hashtags"] = [tweet.entities.get('hashtags') for tweet in tweets]
    
    return data_set

# %%
veri = tweets_df(tweets)

# %%
veri.to_csv("tweetstappen_veri.csv")

# %%
import tweepy

# %%
import pandas as pd

# %%
consumer_key = 'U74zu1DaYRyZwJXqMaBmjTB7y'
consumer_secret = 'qPxEPi9UCoTxK15Inen5tzMZlqhokdpvFr0nws9OXyZbsECYn6'
access_token = '993952599752749056-vRbMlsIIFgFz3u9CjWLM2C5Vj47QFno'
access_token_secret = 'TWfyanQKQ26mXJHzPZZANXvDPiDgmbioKRFuuhf43GUbv'


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
me = api.get_user(screen_name = "mustafa_aktaas")

# %%
me
# Out:
# User(_api=<tweepy.api.API object at 0x00000217C3EBA5E0>, _json={'id': 993952599752749056, 'id_str': '993952599752749056', 'name': 'Mustafa Aktaş', 'screen_name': 'mustafa_aktaas', 'location': '', 'profile_location': None, 'description': '', 'url': 'https://t.co/in88AMiJoR', 'entities': {'url': {'urls': [{'url': 'https://t.co/in88AMiJoR', 'expanded_url': 'http://www.instagram.com/mustafa_aktaas', 'display_url': 'instagram.com/mustafa_aktaas', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 87, 'friends_count': 158, 'listed_count': 0, 'created_at': 'Tue May 08 20:35:41 +0000 2018', 'favourites_count': 708, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 16, 'lang': None, 'status': {'created_at': 'Sat Jan 08 19:03:04 +0000 2022', 'id': 1479891423176675343, 'id_str': '1479891423176675343', 'text': '@bahadr_tryk Sen yazana kadar 8 oldular', 'truncated': False, 'entities': {'hashtags': [], 'symbol
# ...

# %%
me.screen_name
# Out:
# 'mustafa_aktaas'

# %%
me.followers
# Out:
# <bound method User.followers of User(_api=<tweepy.api.API object at 0x00000217C3EBA5E0>, _json={'id': 993952599752749056, 'id_str': '993952599752749056', 'name': 'Mustafa Aktaş', 'screen_name': 'mustafa_aktaas', 'location': '', 'profile_location': None, 'description': '', 'url': 'https://t.co/in88AMiJoR', 'entities': {'url': {'urls': [{'url': 'https://t.co/in88AMiJoR', 'expanded_url': 'http://www.instagram.com/mustafa_aktaas', 'display_url': 'instagram.com/mustafa_aktaas', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 87, 'friends_count': 158, 'listed_count': 0, 'created_at': 'Tue May 08 20:35:41 +0000 2018', 'favourites_count': 708, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 16, 'lang': None, 'status': {'created_at': 'Sat Jan 08 19:03:04 +0000 2022', 'id': 1479891423176675343, 'id_str': '1479891423176675343', 'text': '@bahadr_tryk Sen yazana kadar 8 oldular', 'truncated': False, 'ent
# ...

# %%
# ?me
# Out:
# Type:        User
# String form: User(_api=<tweepy.api.API object at 0x00000217C3EBA5E0>, _json={'id': 993952599752749056, 'id_str <...> ranslator_type='none', withheld_in_countries=[], suspended=False, needs_phone_verification=False)
# File:        c:\anaconda\lib\site-packages\tweepy\models.py
# Docstring:   <no docstring>

# %%
dir(me)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow',
#  'follow_request_sent',
#  'follower_ids',
#  'followers',
#  'followers_count',
#  'following',
#  'friends',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'list_memberships',
#  'list_ownerships',
#  'list_subscriptions',
#  'listed_count',
# ...

# %%
me.location
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 me.location()
#
# TypeError: 'str' object is not callable

# %%
me.id
# Out:
# 993952599752749056

# %%
me.protected
# Out:
# False

# %%
me.lang

# %%
me.language
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 me.language
#
# AttributeError: 'User' object has no attribute 'language'

# %%
me.description
# Out:
# ''

# %%
me.url
# Out:
# 'https://t.co/in88AMiJoR'

# %%
me.verified
# Out:
# False

# %%
me.profile_image_url
# Out:
# 'http://pbs.twimg.com/profile_images/1356858298465742849/0AkIbyvq_normal.jpg'

# %%
search_term = "Fenerbahçe"

# %%
tweets = tweepy.Cursor(api.search_tweets, q = search_term, tweet_mode = ["extended"],count = 1999).items(2000)

# %%
tweets

# %%
for tweet in tweets:
    print(tweet.text)
# Out:
# Atilla bana da suni teneffüs yapar mısın
# #Fenerbahce
# ORUSBUNUN COCUKLARI DYNAMO KIEV 🚀 #Fenerbahce #Fener #DynamoKiev
# RT @resmibetmoney: 🚨 #BETMONEY'DE ETKİNLİK VAKTİ!
#
# ⚽ #Fenerbahce - #DinamoKiev maçında son gol kaçıncı dakikada olur?
#
# Doğru bilen 2 kişiye…
# Gençliğimi çaldın lan #Fenerbahce, ömrümü yedin...
# #Fenerbahçe - Dynamo Kyiv ★ #Gol en el 57'': 0 - [1] Vitaliy Buyalskyi ★ by #SofaScore
# Sabah kadar boş boş da konuşsan seni dinlerim ertem şener yeter ki şu turu geçelim 💛💙 #FBvDK #fenerbahçe
# uzun zamandır bir gole bu kadar çok sevinmemiştim OOOOOHHHHHH #Fenerbahçe #FBvDK
# Burası Kadıköy savaşmanız bile yeter iyiki #Fenerbahçe liyim 💛💙 #FBvDK
# #Fenerbahçe - #DinamoKiev maçının normal süresi 1-1 sona erdi ve maç uzatmalara kaldı
# Fenerbahçe - Dinamo Kiev Uzatma İzleme Linkleri
#
# 👉 https://t.co/3AkkMMTCHy
#
# 👉 https://t.co/PCeWpuLKhk
#
# 👇L… https://t.co/KAmjAXVvGA
# Rossi 90 dk oynadığı, Arda nin dakika alamadığı dünyada kimse adaletden bahsetmesin!
# ...

# %%
def tweets_df(tweets):
    id_list = [tweet.id for tweet  in tweets]
    import pandas as pd
    data_set = pd.DataFrame(id_list, columns = ["id"])  
    data_set["text"] = [tweet.text for tweet in tweets]
    data_set["created_at"] = [tweet.created_at for tweet in tweets]
    data_set["retweet_count"] = [tweet.retweet_count for tweet in tweets]
    data_set["user_screen_name"] = [tweet.author.screen_name for tweet in tweets]
    data_set["user_followers_count"] = [tweet.author.followers_count for tweet in tweets]
    data_set["user_location"] = [tweet.author.location for tweet in tweets]
    data_set["Hashtags"] = [tweet.entities.get('hashtags') for tweet in tweets]
    
    return data_set

# %%
data = tweets_df(tweets)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File C:\Anaconda\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File C:\Anaconda\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [id, text, created_at, retweet_count, user_screen_name, user_followers_count, user_location, Hashtags]
# Index: []

# %%
data.to_csv("fener.csv")
